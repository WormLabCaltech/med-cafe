# %% [markdown]
# # Table of Contents
#  <p>

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import epistasis as epi
import sklearn.decomposition
import tissue_enrichment_analysis as ea

from matplotlib import rc

import os
rc('text', usetex=True)
rc('text.latex', preamble=r'\usepackage{cmbright}')
rc('font', **{'family': 'sans-serif', 'sans-serif': ['Helvetica']})


# %matplotlib inline

# This enables SVG graphics inline. 
# %config InlineBackend.figure_formats = {'png', 'retina'}

# JB's favorite Seaborn settings for notebooks
rc = {'lines.linewidth': 2, 
      'axes.labelsize': 18, 
      'axes.titlesize': 18, 
      'axes.facecolor': 'DFDFE5'}
sns.set_context('notebook', rc=rc)
sns.set_style("dark")

mpl.rcParams['xtick.labelsize'] = 16 
mpl.rcParams['ytick.labelsize'] = 16 
mpl.rcParams['legend.fontsize'] = 14

# %%
tissue = tea.fetch_dictionary('tissue')
pheno = tea.fetch_dictionary('phenotype')
go = tea.fetch_dictionary('go')

# %%
strains =['ps4187', 'ps4087', 'ps4176', 'ew15', 'mt21245', 'mt4866','n2731', 'n2376', 'n767', 'n2731-n767', 'tm1489',
          'n3809', 'n3917', 'n745', 'n767-tm1489', 'n2731-tm1489',
          'ia4', 'ok1402', 'ok161', 'sa307', 'sa307-ok161', 'sa307-ia4',
          'q71']

strain_dict = {}
for i, g in enumerate(strains):
    strain_dict[g] = i

# %%
q = 0.1

# %%
genmap = pd.read_csv('../sleuth/rna_seq_info.txt', sep=' ', comment='#')
tidy  = pd.read_csv('../input/quantifications.csv')

# %%
# stress = epi.find_overlap(['sa307', 'sa307-ok161'], tidy)
# tidy = tidy[(tidy.strain.isin(['mt21245', 'mt4866'])) & (~tidy.target_id.isin(stress))]

# %%
len(stress)
# Out:
# 2966

# %%
print('mt2124 DE genes sans stress: {0}'.format(len(tidy[(tidy.strain == 'mt21245') & (tidy.qval < q)])))
print('mt4866 DE genes sans stress: {0}'.format(len(tidy[(tidy.strain == 'mt4866') & (tidy.qval < q)])))
# Out:
# mt2124 DE genes sans stress: 3096
# mt4866 DE genes sans stress: 899

# %%
ras = epi.find_overlap(['mt21245', 'mt4866'], tidy)

gf = tidy[(tidy.strain == 'mt21245') & (tidy.target_id.isin(ras))].copy()
lf = tidy[(tidy.strain == 'mt4866') & (tidy.target_id.isin(ras))].copy()

lf['standardized_b'] = lf.b.values/gf.b.values

ras_ac = lf[lf.standardized_b < 0].ens_gene.unique()
ras_corr = lf[lf.standardized_b > 0].ens_gene.unique()

ind = (tidy.qval < q) & (tidy.strain == 'mt21245')
notin = (~tidy.ens_gene.isin(ras_ac)) & (~tidy.ens_gene.isin(ras_corr))
ras_gf = tidy[ind & notin]


ind = (tidy.qval < q) & (tidy.strain == 'mt4866')
notin = (~tidy.ens_gene.isin(ras_ac)) & (~tidy.ens_gene.isin(ras_corr))
ras_lf = tidy[ind & notin]


print('ras overlap: {0}'.format(len(ras)))
print('ras anticorr: {0}'.format(len(ras_ac)))
print('ras corr: {0}'.format(len(ras_corr)))
print('ras gf: {0}'.format(len(ras_gf)))
print('ras lf: {0}'.format(len(ras_lf)))
# Out:
# ras overlap: 269
# ras anticorr: 73
# ras corr: 190
# ras gf: 2817
# ras lf: 621

# %%
tea_ = ea.enrichment_analysis(ras_gf.ens_gene.unique(), tissue, show=False)
tea_
# Out:
#                                 Tissue     Expected  Observed  \
# 131                  male WBbt:0007850   364.351076      1240
# 99    reproductive system WBbt:0005747  1423.246391      1974
# 240    amphid sheath cell WBbt:0006754    88.810575       219
# 212                oocyte WBbt:0006797    21.348696        51
# 201                    AB WBbt:0004015    16.225009        32
# 108     epithelial system WBbt:0005730   564.601844       645
# 247              ABalpppa WBbt:0006649     5.550661        14
# 3                ABplpppa WBbt:0006423     5.266012        13
# 53               ABplpppp WBbt:0006647     5.408336        13
# 275  male distal tip cell WBbt:0006864    88.525926       117
# 82                  Psub2 WBbt:0006873     6.404609        14
# 48               ABpraapp WBbt:0006335     4.696713        11
# 250              ABalppaa WBbt:0005944     5.977635        13
# 256                  Z1.p WBbt:0007023    88.241276       115
# 237                  Z4.a WBbt:0007025    88.098952       115
# 33               ABpraaap WBbt:0006534     4.696713        11
# 150              ABalpaaa WBbt:0006557     5.835310        13
# 54               ABprapap WBbt:0006678     4.839038        11
# 172              ABalappa WBbt:0006157     4.839038        11
# 222              ABprpaaa WBbt:0006167     4.981362        11
# 180              ABalppap WBbt:0006112     4.981362        11
# 171              ABplpapp WBbt:0006420     4.981362        11
# 224              ABalpapa WBbt:0006573     5.692986        12
# 70               ABarpaaa WBbt:0006398     6.404609        13
# 231  cephalic sheath cell WBbt:0008406    43.124366        60
# 167                  Caap WBbt:0005921     5.266012        11
# 110              ABalpaap WBbt:0005934     5.266012        11
# 68               ABprpaap WBbt:0006253     4.696713        10
# 119                 Cpapp WBbt:0005897     6.689258        13
# 196              ABarappa WBbt:0006005     4.696713        10
# 4                ABplpapa WBbt:0006087     5.408336        11
# 181                  Cppa WBbt:0006168     6.689258        13
# 143              ABalaapa WBbt:0006130     4.839038        10
# 155              ABprpppp WBbt:0006179     4.839038        10
# 202              ABprpapa WBbt:0006259     4.839038        10
# 271              ABpraapa WBbt:0006302     5.550661        11
# 12                   Cppp WBbt:0006268     5.550661        11
#
#      Enrichment Fold Change       P value       Q value
# 131                3.403311  0.000000e+00  0.000000e+00
# 99                 1.386970  1.055289e-57  1.466852e-55
# 240                2.465923  1.088077e-39  1.008285e-37
# 212                2.388905  2.832873e-10  1.968846e-08
# 201                1.972264  3.695849e-05  2.054892e-03
# 108                1.142398  1.121203e-04  5.194907e-03
# 247                2.522222  1.651727e-04  6.559716e-03
# 3                  2.468661  3.309609e-04  1.150089e-02
# 53                 2.403697  4.557815e-04  1.407858e-02
# 275                1.321647  6.493009e-04  1.805056e-02
# 82                 2.185926  9.777816e-04  2.471121e-02
# 48                 2.342063  1.311993e-03  2.534420e-02
# 250                2.174773  1.428194e-03  2.534420e-02
# 256                1.303245  1.191977e-03  2.534420e-02
# 237                1.305350  1.124504e-03  2.534420e-02
# 33                 2.342063  1.311993e-03  2.534420e-02
# 150                2.227816  1.093994e-03  2.534420e-02
# 54                 2.273179  1.767475e-03  2.729768e-02
# 172                2.273179  1.767475e-03  2.729768e-02
# 222                2.208231  2.345016e-03  3.259572e-02
# 180                2.208231  2.345016e-03  3.259572e-02
# 171                2.208231  2.345016e-03  3.259572e-02
# 224                2.107857  2.698430e-03  3.261581e-02
# 70                 2.029788  2.975208e-03  3.446283e-02
# 231                1.391325  3.041456e-03  3.446283e-02
# 167                2.088867  3.959767e-03  4.233904e-02
# 110                2.088867  3.959767e-03  4.233904e-02
# 68                 2.129149  4.513737e-03  4.481496e-02
# 119                1.943414  4.620998e-03  4.481496e-02
# 196                2.129149  4.513737e-03  4.481496e-02
# 4                  2.033897  5.048959e-03  4.481496e-02
# 181                1.943414  4.620998e-03  4.481496e-02
# 143                2.066527  5.827166e-03  4.908946e-02
# 155                2.066527  5.827166e-03  4.908946e-02
# 202                2.066527  5.827166e-03  4.908946e-02
# 271                1.981746  6.363825e-03  4.914287e-02
# 12                 1.981746  6.363825e-03  4.914287e-02

# %%
pea = ea.enrichment_analysis(ras_gf.ens_gene.unique(), pheno, show=False)
pea
# Out:
#                                                 Tissue   Expected  Observed  \
# 196  linker cell migration variant WBPhenotype:0001511   6.635976        25
# 167       lipid metabolism variant WBPhenotype:0000725  73.765126       118
# 160            fat content reduced WBPhenotype:0001183  44.624535        73
# 97           fat content increased WBPhenotype:0001184  25.293648        42
# 163            mRNA levels reduced WBPhenotype:0000137  12.406390        24
# 211   neuropil development variant WBPhenotype:0000945   9.809704        20
# 94    ectopic expression transgene WBPhenotype:0001276  11.829349        23
# 60   ventral cord patterning variant WBPhenotype:00...   8.078580        17
# 23   transgene expression undetectable WBPhenotype:...   6.443629        14
# 44      axon fasciculation variant WBPhenotype:0000632   8.559448        17
#
#      Enrichment Fold Change       P value       Q value
# 196                3.767343  3.826431e-10  8.265092e-08
# 167                1.599672  1.425114e-07  1.539123e-05
# 160                1.635871  1.133377e-05  8.160311e-04
# 97                 1.660496  4.099866e-04  2.213928e-02
# 163                1.934487  5.341180e-04  2.307390e-02
# 211                2.038798  6.322923e-04  2.307390e-02
# 94                 1.944317  6.162698e-04  2.307390e-02
# 60                 2.104330  9.186366e-04  2.480319e-02
# 23                 2.172689  1.494880e-03  3.587711e-02
# 44                 1.986109  1.842144e-03  3.979031e-02

# %%
gea = ea.enrichment_analysis(ras_gf.ens_gene.unique(), go, show=False)
gea[gea['Enrichment Fold Change'] > 3]
# Out:
#                                                 Tissue    Expected  Observed  \
# 201                   developmental process GO:0032502  186.932061       652
# 175                      embryo development GO:0009790  108.209968       354
# 161                            reproduction GO:0000003  104.589805       343
# 5                  regulation of cell shape GO:0008360    3.323968        69
# 138            peptidyl-serine modification GO:0018209    5.002407        79
# 74                    immune system process GO:0002376   11.288327        71
# 244                  multi-organism process GO:0051704   25.439874       105
# 208                                   aging GO:0007568   31.067582       101
# 67                         side of membrane GO:0098552    3.949269        30
# 49                              oviposition GO:0018991   13.592067        49
# 71               nervous system development GO:0007399   14.908490        51
# 264                    localization of cell GO:0051674   12.209823        44
# 176  post-embryonic animal organ development GO:004...   12.506018        43
# 58            positive regulation of growth GO:0045927   13.032587        44
# 23            multicellular organism growth GO:0035264   13.624978        45
# 66              response to biotic stimulus GO:0009607    5.792261        27
# 57                       neuron development GO:0048666   10.959221        38
# 43               meiotic cell cycle process GO:1903046   12.308555        40
# 256                               cell body GO:0044297    6.154277        24
# 28             digestive system development GO:0055123    3.521431        16
# 271  cell morphogenesis involved in differentiation...    7.009952        23
# 177                        tube development GO:0035295    3.718895        16
# 268                            phagocytosis GO:0006909    4.410017        17
# 131   monocarboxylic acid catabolic process GO:0072329    3.916358        15
# 98                identical protein binding GO:0042802    4.772033        16
# 243                   membrane invagination GO:0010324    3.422700        12
#
#      Enrichment Fold Change        P value        Q value
# 201                3.487898  3.076233e-168  9.228698e-166
# 175                3.271418   8.637915e-84   1.295687e-81
# 161                3.279478   1.665717e-81   1.665717e-79
# 5                 20.758323   4.550859e-79   3.413144e-77
# 138               15.792397   5.161552e-76   3.096931e-74
# 74                 6.289683   3.611371e-36   1.547730e-34
# 244                4.127379   8.309687e-35   3.116133e-33
# 208                3.250977   3.726869e-25   1.118061e-23
# 67                 7.596343   2.915447e-19   7.951220e-18
# 49                 3.605044   4.515978e-15   8.467458e-14
# 71                 3.420870   1.151915e-14   2.032792e-13
# 264                3.603656   9.433192e-14   1.572199e-12
# 176                3.438345   8.833686e-13   1.325053e-11
# 58                 3.376152   9.478744e-13   1.354106e-11
# 23                 3.302758   1.186813e-12   1.548017e-11
# 66                 4.661392   6.475120e-12   8.093901e-11
# 57                 3.467400   1.176567e-11   1.411881e-10
# 43                 3.249772   2.910847e-11   3.358670e-10
# 256                3.899727   3.548753e-09   3.802236e-08
# 28                 4.543607   8.485492e-08   8.211767e-07
# 271                3.281049   1.968725e-07   1.797997e-06
# 177                4.302353   1.917864e-07   1.797997e-06
# 268                3.854860   4.836814e-07   4.267777e-06
# 131                3.830089   2.022473e-06   1.733548e-05
# 98                 3.352869   6.573338e-06   5.329734e-05
# 243                3.506004   3.932547e-05   2.808962e-04

# %%
tea = ea.enrichment_analysis(ras_lf.ens_gene.unique(), tissue, show=False)
tea
# Out:
#                                            Tissue    Expected  Observed  \
# 89   spermathecal-uterine valve cell WBbt:0008217   20.189172        54
# 93                           Nucleus WBbt:0006803   19.863540        54
# 78                     gon herm sujn WBbt:0008210   19.646452        54
# 56     spermathecal-uterine junction WBbt:0006756   21.301747        55
# 139                    somatic gonad WBbt:0005785   33.540076        66
# 63                     hermaphrodite WBbt:0007849   81.869263       121
# 52                         intestine WBbt:0005772  151.690149       195
# 128               reproductive tract WBbt:0005744   66.890200        94
# 154                              hmc WBbt:0004697    1.655295         6
#
#      Enrichment Fold Change       P value       Q value
# 89                 2.674701  4.331298e-11  4.305777e-09
# 93                 2.718549  2.349354e-11  4.305777e-09
# 78                 2.748588  1.548841e-11  4.305777e-09
# 56                 2.581948  1.110762e-10  7.719799e-09
# 139                1.967795  1.192552e-07  6.630589e-06
# 63                 1.477966  1.123997e-05  5.207851e-04
# 52                 1.285515  1.729151e-04  6.867200e-03
# 128                1.405288  5.008505e-04  1.740456e-02
# 154                3.624732  1.303964e-03  4.027801e-02

# %%
pea = ea.enrichment_analysis(ras_lf.ens_gene.unique(), pheno, show=False)
pea
# Out:
#                                                Tissue  Expected  Observed  \
# 47  mitochondria alignment variant WBPhenotype:000...  3.418119        11
#
#     Enrichment Fold Change   P value   Q value
# 47                3.218144  0.000173  0.037388

# %%
gea_lf = ea.enrichment_analysis(ras_lf.ens_gene.unique(), go, show=False)
gea_lf[gea_lf['Enrichment Fold Change'] > 3]
# Out:
#                                                 Tissue   Expected  Observed  \
# 167                   developmental process GO:0032502  41.544344       136
# 134                            reproduction GO:0000003  23.244353        82
# 146                      embryo development GO:0009790  24.048909        82
# 5                post-embryonic development GO:0009791  17.166298        68
# 115                         collagen trimer GO:0005581   1.397002        16
# 127                                   aging GO:0007568   6.904553        26
# 128                              cell death GO:0008219   5.602635        22
# 47            positive regulation of growth GO:0045927   2.896401        15
# 17            multicellular organism growth GO:0035264   3.028056        15
# 199                   immune system process GO:0002376   2.508752        13
# 98   development of primary sexual characteristics ...   7.270260        23
# 154         reproductive system development GO:0061458   7.379972        23
# 133                   membrane invagination GO:0010324   0.760671         7
# 34                   supramolecular complex GO:0099080   4.227576        16
# 62                        contractile fiber GO:0043292   1.543285         9
# 197                  multi-organism process GO:0051704   5.653834        18
# 161                            phagocytosis GO:0006909   0.980095         7
# 90                      cuticle development GO:0042335   1.023980         7
# 36               meiotic cell cycle process GO:1903046   2.735490        11
# 163                       organelle fission GO:0048285   5.193043        16
# 58               nervous system development GO:0007399   3.313308        12
# 20                       neuron development GO:0048666   2.435610        10
# 13                            molting cycle GO:0042303   3.466905        12
# 211                    localization of cell GO:0051674   2.713548        10
# 190        glucuronosyltransferase activity GO:0015020   0.826498         5
# 219  cell morphogenesis involved in differentiation...   1.557913         7
# 24                  muscle cell development GO:0055001   1.243405         6
# 45     striated muscle cell differentiation GO:0051146   1.243405         6
# 206                               cell body GO:0044297   1.367745         6
# 41                            lytic vacuole GO:0000323   1.002038         5
# 225                inductive cell migration GO:0040039   1.067865         5
# 203            myosin filament organization GO:0031033   1.075179         5
# 61                  lipid catabolic process GO:0016042   1.960191         7
# 10                   actin filament binding GO:0051015   0.767985         4
# 121                 cell part morphogenesis GO:0032990   1.587169         6
# 22             digestive system development GO:0055123   0.782614         4
# 153  cellular component assembly involved in morpho...   1.192206         5
# 148                        tube development GO:0035295   0.826498         4
# 55              response to biotic stimulus GO:0009607   1.287290         5
# 230       actomyosin structure organization GO:0031032   1.309232         5
# 185                  RNA polymerase complex GO:0030880   1.835850         6
# 39                      poly(A) RNA binding GO:0044822   1.089808         4
#
#      Enrichment Fold Change       P value       Q value
# 167                3.273611  8.661666e-33  2.598500e-30
# 134                3.527739  1.893923e-22  2.840884e-20
# 146                3.409718  1.525863e-21  1.346361e-19
# 5                  3.961250  1.346361e-21  1.346361e-19
# 115               11.453100  1.134460e-13  6.806760e-12
# 127                3.765631  4.125474e-09  2.062737e-07
# 128                3.926724  2.349490e-08  8.810589e-07
# 47                 5.178840  6.118043e-08  2.039348e-06
# 17                 4.953673  1.117494e-07  3.352481e-06
# 199                5.181860  3.552715e-07  9.689222e-06
# 98                 3.163573  6.154061e-07  1.538515e-05
# 154                3.116543  7.983347e-07  1.842311e-05
# 133                9.202401  1.119815e-06  2.399604e-05
# 34                 3.784675  1.985559e-06  3.971117e-05
# 62                 5.831718  4.424137e-06  8.295256e-05
# 197                3.183680  6.783697e-06  1.197123e-04
# 161                7.142162  7.467192e-06  1.244532e-04
# 90                 6.836069  1.029498e-05  1.625523e-04
# 36                 4.021217  2.648564e-05  3.783662e-04
# 163                3.081045  2.800380e-05  3.818700e-04
# 58                 3.621758  3.933198e-05  5.130259e-04
# 20                 4.105747  4.365308e-05  5.456635e-04
# 13                 3.461301  6.212197e-05  7.454637e-04
# 211                3.685212  1.135533e-04  1.310231e-03
# 190                6.049619  1.974022e-04  2.193358e-03
# 219                4.493191  1.987126e-04  2.193358e-03
# 24                 4.825460  2.834108e-04  2.931836e-03
# 45                 4.825460  2.834108e-04  2.931836e-03
# 206                4.386782  5.020989e-04  4.859021e-03
# 41                 4.989831  5.537317e-04  5.191235e-03
# 225                4.682239  7.727615e-04  7.025104e-03
# 203                4.650387  8.007053e-04  7.065047e-03
# 61                 3.571081  9.040585e-04  7.749073e-03
# 10                 5.208434  1.099516e-03  9.162635e-03
# 121                3.780315  1.197871e-03  9.698129e-03
# 22                 5.111080  1.196103e-03  9.698129e-03
# 153                4.193907  1.362925e-03  1.048403e-02
# 148                4.839695  1.523583e-03  1.142687e-02
# 55                 3.884130  2.008367e-03  1.454710e-02
# 230                3.819033  2.185471e-03  1.524747e-02
# 185                3.268240  2.720286e-03  1.813524e-02
# 39                 3.670373  5.009159e-03  3.197336e-02

# %%
tea_ac = ea.enrichment_analysis(ras_ac, tissue, show=False)
tea_ac
# Out:
#                                           Tissue  Expected  Observed  \
# 17                    somatic gonad WBbt:0005785  3.267622        14
# 29                    gon herm sujn WBbt:0008210  1.914044        10
# 19    spermathecal-uterine junction WBbt:0006756  2.075310        10
# 18                          Nucleus WBbt:0006803  1.935194        10
# 11  spermathecal-uterine valve cell WBbt:0008217  1.966918        10
# 13                    hermaphrodite WBbt:0007849  7.976065        18
#
#     Enrichment Fold Change   P value   Q value
# 17                4.284461  0.000001  0.000386
# 29                5.224540  0.000005  0.000631
# 19                4.818557  0.000010  0.000631
# 18                5.167441  0.000005  0.000631
# 11                5.084095  0.000006  0.000631
# 13                2.256752  0.000488  0.022589

# %%
pea_ac = ea.enrichment_analysis(ras_ac, pheno, show=False)
pea_ac
# Out:
# Empty DataFrame
# Columns: [Tissue, Expected, Observed, Enrichment Fold Change, P value, Q value]
# Index: []

# %%
gea_ac = ea.enrichment_analysis(ras_ac, go, show=False)
gea_ac
# Out:
#                                     Tissue  Expected  Observed  \
# 2    post-embryonic development GO:0009791  1.524448         9
# 3                 lytic vacuole GO:0000323  0.088986         2
# 45  response to biotic stimulus GO:0009607  0.114317         2
# 29           embryo development GO:0009790  2.135656         8
# 25        developmental process GO:0032502  3.689334        11
#
#     Enrichment Fold Change   P value   Q value
# 2                 5.903776  0.000004  0.001193
# 3                22.475525  0.000106  0.015931
# 45               17.495153  0.000222  0.022210
# 29                3.745921  0.000342  0.025623
# 25                2.981568  0.000391  0.025623

# %%
tea_corr = ea.enrichment_analysis(ras_corr, tissue, show=False)
tea_corr
# Out:
# Empty DataFrame
# Columns: [Tissue, Expected, Observed, Enrichment Fold Change, P value, Q value]
# Index: []

# %%
pea_corr = ea.enrichment_analysis(ras_corr, pheno, show=False)
pea_corr
# Out:
# Empty DataFrame
# Columns: [Tissue, Expected, Observed, Enrichment Fold Change, P value, Q value]
# Index: []

# %%
gea_corr = ea.enrichment_analysis(ras_corr, go, show=False)
ind = (gea_corr['Expected'] > 1) | (gea_corr['Observed'] > 4)
gea_corr[(gea_corr['Enrichment Fold Change'] > 3) & (ind)]
# Out:
#                                                 Tissue   Expected  Observed  \
# 115                   developmental process GO:0032502  17.484993        62
# 119                      embryo development GO:0009790  10.121595        42
# 109                            reproduction GO:0000003   9.782977        33
# 3                post-embryonic development GO:0009791   7.224873        26
# 163            myosin filament organization GO:0031033   0.452517         7
# 19   cellular component assembly involved in morpho...   0.501770         7
# 33     striated muscle cell differentiation GO:0051146   0.523318         7
# 17                  muscle cell development GO:0055001   0.523318         7
# 186       actomyosin structure organization GO:0031032   0.551024         7
# 76   development of primary sexual characteristics ...   3.059874        14
# 169         reproductive system development GO:0061458   3.106049        14
# 103                              cell death GO:0008219   2.358011        10
# 157                  multi-organism process GO:0051704   2.379560        10
# 81             actin filament-based process GO:0030029   1.597660         8
# 102                                   aging GO:0007568   2.905957        11
# 25               meiotic cell cycle process GO:1903046   1.151301         6
# 93                   chromosome segregation GO:0007059   1.231338         6
# 14            multicellular organism growth GO:0035264   1.274434         6
# 133                       organelle fission GO:0048285   2.185624         8
# 35            positive regulation of growth GO:0045927   1.219024         5
# 29                              oviposition GO:0018991   1.271356         5
#
#      Enrichment Fold Change       P value       Q value
# 115                3.545898  9.917349e-18  2.975205e-15
# 119                4.149544  7.177740e-15  1.076661e-12
# 109                3.373206  8.550326e-10  8.550326e-08
# 3                  3.598679  1.054614e-08  7.909603e-07
# 163               15.469048  2.396128e-08  1.437677e-06
# 19                13.950613  5.346464e-08  2.673232e-06
# 33                13.376176  7.397818e-08  3.170493e-06
# 17                13.376176  7.397818e-08  3.170493e-06
# 186               12.703631  1.100203e-07  3.667342e-06
# 76                 4.575352  7.456211e-07  2.236863e-05
# 169                4.507334  8.962325e-07  2.444270e-05
# 103                4.240862  3.401985e-05  8.504962e-04
# 157                4.202458  3.690688e-05  8.516971e-04
# 81                 5.007322  4.177492e-05  8.951768e-04
# 102                3.785328  4.902790e-05  9.805580e-04
# 25                 5.211497  1.856428e-04  3.480802e-03
# 93                 4.872750  2.785233e-04  4.915117e-03
# 14                 4.707971  3.421576e-04  5.556359e-03
# 133                3.660282  4.264353e-04  6.091933e-03
# 35                 4.101641  1.569362e-03  1.743736e-02
# 29                 3.932809  1.936393e-03  2.074707e-02

# %%
tidy[tidy.ens_gene.isin(ras_ac)].ext_gene.unique()
# Out:
# array(['pdi-6', 'B0513.4', 'gck-4', 'C17F4.7', 'C17G1.2', 'C18E9.5',
#        'best-7', 'C32H11.4', 'C42D4.1', 'nspc-20', 'ddo-3', 'ifd-2',
#        'F32H5.1', 'nhr-8', 'F37H8.5', 'cpr-4', 'F48E3.4', 'skpo-1',
#        'F52E1.14', 'lys-5', 'lys-6', 'lpin-1', 'cah-3', 'M28.10', 'dpy-27',
#        'T04G9.7', 'lin-59', 'pod-2', 'Y105C5B.15', 'cls-3', 'ZK1307.1',
#        'ZK673.1'], dtype=object)
