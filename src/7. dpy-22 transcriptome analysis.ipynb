# %% [markdown]
# # Table of Contents
#  <p>

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import epistasis as epi
import sklearn.decomposition
import tissue_enrichment_analysis as ea

from matplotlib import rc

import os
rc('text', usetex=True)
rc('text.latex', preamble=r'\usepackage{cmbright}')
rc('font', **{'family': 'sans-serif', 'sans-serif': ['Helvetica']})


# %matplotlib inline

# This enables SVG graphics inline. 
# %config InlineBackend.figure_formats = {'png', 'retina'}

# JB's favorite Seaborn settings for notebooks
rc = {'lines.linewidth': 2, 
      'axes.labelsize': 18, 
      'axes.titlesize': 18, 
      'axes.facecolor': 'DFDFE5'}
sns.set_context('notebook', rc=rc)
sns.set_style("dark")

mpl.rcParams['xtick.labelsize'] = 16 
mpl.rcParams['ytick.labelsize'] = 16 
mpl.rcParams['legend.fontsize'] = 14

# %%
tissue = ea.fetch_dictionary('tissue')
pheno = ea.fetch_dictionary('phenotype')
go = ea.fetch_dictionary('go')

# %%
strains =['ps4187', 'ps4087', 'ps4176', 'ew15', 'mt21245', 'mt4866','n2731', 'n2376', 'n767', 'n2731-n767', 'tm1489',
          'n3809', 'n3917', 'n745', 'n767-tm1489', 'n2731-tm1489',
          'ia4', 'ok1402', 'ok161', 'sa307', 'sa307-ok161', 'sa307-ia4',
          'q71']

strain_dict = {}
for i, g in enumerate(strains):
    strain_dict[g] = i

# %%
q = 0.1

# %%
genmap = pd.read_csv('../sleuth/rna_seq_info.txt', sep=' ', comment='#')
tidy  = pd.read_csv('../input/quantifications.csv')

# %%
stress = epi.find_overlap(['sa307', 'sa307-ok161'], tidy)
tidy = tidy[(tidy.strain.isin(['ps4187', 'ps4087', 'ps4176'])) & (~tidy.target_id.isin(stress))]

# %%
print('ps4087 DE genes sans stress: {0}'.format(len(tidy[(tidy.strain == 'ps4087') & (tidy.qval < q)])))
print('ps4187 DE genes sans stress: {0}'.format(len(tidy[(tidy.strain == 'ps4187') & (tidy.qval < q)])))
print('ps4176 DE genes sans stress: {0}'.format(len(tidy[(tidy.strain == 'ps4176') & (tidy.qval < q)])))
# Out:
# ps4087 DE genes sans stress: 1793
# ps4187 DE genes sans stress: 229
# ps4176 DE genes sans stress: 2377

# %%
weak = epi.find_overlap(['ps4187'], tidy)
strong = tidy[(tidy.qval < q) & (tidy.strain == 'ps4087') & (~tidy.target_id.isin(weak))].ens_gene
weak = tidy[tidy.target_id.isin(weak)].ens_gene.unique()

# %%
ea.enrichment_analysis(strong, tissue, show=False)
# Out:
#                                            Tissue    Expected  Observed  \
# 70                           Nucleus WBbt:0006803   74.367789       123
# 78                     gon herm sujn WBbt:0008210   73.555027       123
# 252  spermathecal-uterine valve cell WBbt:0008217   75.586933       124
# 253    spermathecal-uterine junction WBbt:0006756   79.752342       124
# 265                            Psub1 WBbt:0006874   23.671714        47
# 129                    somatic gonad WBbt:0005785  125.571841       175
# 161                  muscular system WBbt:0005737  510.618182       587
# 213                    hermaphrodite WBbt:0007849  306.513143       362
# 135                        intestine WBbt:0005772  567.917954       638
# 222           outer labial sensillum WBbt:0005501  298.487111       346
#
#      Enrichment Fold Change       P value   Q value
# 70                 1.653942  1.155666e-08  0.000002
# 78                 1.672217  6.000848e-09  0.000002
# 252                1.640495  1.648136e-08  0.000002
# 253                1.554813  3.404470e-07  0.000024
# 265                1.985492  1.665285e-06  0.000093
# 129                1.393625  3.297910e-06  0.000153
# 161                1.149587  1.488912e-04  0.005913
# 213                1.181026  4.028246e-04  0.013998
# 135                1.123402  7.630685e-04  0.023570
# 222                1.159179  1.750731e-03  0.048670

# %%
ea.enrichment_analysis(strong, pheno, show=False)
# Out:
#                                                 Tissue   Expected  Observed  \
# 1            avoids bacterial lawn WBPhenotype:0000402  48.456672        78
# 130  diplotene absent during oogenesis WBPhenotype:...  11.677621        24
# 128              gonad vesiculated WBPhenotype:0001979  22.154740        38
# 123  pleiotropic defects severe early emb WBPhenoty...  13.205535        25
# 64                   rachis absent WBPhenotype:0001942   9.385752        19
# 133                  rachis narrow WBPhenotype:0001941  30.449125        47
#
#      Enrichment Fold Change   P value   Q value
# 1                  1.609685  0.000009  0.002042
# 130                2.055213  0.000179  0.019352
# 128                1.715209  0.000329  0.023716
# 123                1.893146  0.000546  0.029478
# 64                 2.024345  0.000809  0.034932
# 133                1.543558  0.001013  0.036474

# %%
_ = ea.enrichment_analysis(strong, go, show=False)
_[_['Enrichment Fold Change'] > 4]
# Out:
#                                                 Tissue   Expected  Observed  \
# 54               post-embryonic development GO:0009791  67.075721       271
# 70                                    aging GO:0007568  26.978901       113
# 68                    immune system process GO:0002376   9.802715        43
# 103                 muscle cell development GO:0055001   4.858489        26
# 33   cellular component assembly involved in morpho...   4.658433        25
# 114    striated muscle cell differentiation GO:0051146   4.858489        25
# 141       actomyosin structure organization GO:0031032   5.115703        25
# 156                         collagen trimer GO:0005581   5.458655        25
# 13             myosin filament organization GO:0031033   4.201164        21
# 188                       contractile fiber GO:0043292   6.030242        25
# 201                inductive cell migration GO:0040039   4.172584        19
#
#      Enrichment Fold Change       P value       Q value
# 54                 4.040210  9.839091e-84  7.379318e-82
# 70                 4.188458  1.291655e-37  7.749932e-36
# 68                 4.386540  1.752900e-16  4.780636e-15
# 103                5.351459  6.445881e-13  1.208603e-11
# 33                 5.366611  1.540048e-12  2.717732e-11
# 114                5.145633  4.149531e-12  6.915884e-11
# 141                4.886914  1.376369e-11  2.173214e-10
# 156                4.579883  6.053495e-11  8.647850e-10
# 13                 4.998615  2.744732e-10  3.430915e-09
# 188                4.145771  5.536343e-10  6.388088e-09
# 201                4.553533  8.331593e-09  9.257326e-08

# %%
ea.enrichment_analysis(weak, tissue, show=False)
# Out:
#                                            Tissue   Expected  Observed  \
# 83   spermathecal-uterine valve cell WBbt:0008217  11.115726        28
# 62                     gon herm sujn WBbt:0008210  10.816916        28
# 44                           Nucleus WBbt:0006803  10.936440        28
# 92     spermathecal-uterine junction WBbt:0006756  11.728286        29
# 63                     hermaphrodite WBbt:0007849  45.075462        71
# 103                    somatic gonad WBbt:0005785  18.466447        35
#
#      Enrichment Fold Change   P value   Q value
# 83                 2.518954  0.000004  0.000679
# 62                 2.588538  0.000002  0.000679
# 44                 2.560248  0.000003  0.000679
# 92                 2.472655  0.000004  0.000679
# 63                 1.575136  0.000091  0.005034
# 103                1.895329  0.000154  0.007157

# %%
ea.enrichment_analysis(weak, go, show=False)
# Out:
#                                                 Tissue   Expected  Observed  \
# 47                    immune system process GO:0002376   1.098107        15
# 157                      embryo development GO:0009790  10.526458        38
# 57                    developmental process GO:0032502  18.184393        52
# 75              response to biotic stimulus GO:0009607   0.563460         8
# 85                             reproduction GO:0000003  10.174296        31
# 49                                    aging GO:0007568   3.022195        14
# 38               post-embryonic development GO:0009791   7.513868        22
# 0                             lytic vacuole GO:0000323   0.438602         5
# 88           organic acid metabolic process GO:0006082   6.380545        19
# 164        glucuronosyltransferase activity GO:0015020   0.361767         4
# 155   monocarboxylic acid catabolic process GO:0072329   0.380976         4
# 99                  lipid catabolic process GO:0016042   0.857996         5
# 45                          plasma membrane GO:0005886   6.220471        16
# 61          intrinsic component of membrane GO:0031224  32.014776        51
# 126                       contractile fiber GO:0043292   0.675512         4
# 167                           vacuolar part GO:0044437   0.400185         3
# 105  RNA polymerase II regulatory region DNA bindin...   0.425797         3
# 10                      cuticle development GO:0042335   0.448207         3
# 92   development of primary sexual characteristics ...   3.182269         9
# 121         reproductive system development GO:0061458   3.230291         9
# 114                      symporter activity GO:0015293   0.982854         4
# 63                                cytoplasm GO:0005737  25.973588        40
#
#      Enrichment Fold Change       P value       Q value
# 47                13.659873  5.055593e-14  1.516678e-11
# 157                3.609951  7.897545e-12  1.184632e-09
# 57                 2.859595  1.284840e-11  1.284840e-09
# 75                14.197990  7.685551e-09  5.764163e-07
# 85                 3.046894  2.682156e-08  1.609293e-06
# 49                 4.632395  6.399400e-07  3.199700e-05
# 38                 2.927919  3.618834e-06  1.550929e-04
# 0                 11.399846  6.106143e-06  2.289804e-04
# 88                 2.977802  1.088836e-05  3.629453e-04
# 164               11.056841  3.512700e-05  1.053810e-03
# 155               10.499354  4.498869e-05  1.226964e-03
# 99                 5.827533  2.536842e-04  6.069866e-03
# 45                 2.572153  2.427946e-04  6.069866e-03
# 61                 1.593014  5.721554e-04  1.226047e-02
# 126                5.921436  6.428247e-04  1.285649e-02
# 167                7.496538  7.445616e-04  1.396053e-02
# 105                7.045619  9.379674e-04  1.655237e-02
# 10                 6.693338  1.134056e-03  1.890094e-02
# 92                 2.828171  1.624198e-03  2.564523e-02
# 121                2.786127  1.810014e-03  2.715021e-02
# 114                4.069782  3.313316e-03  4.733308e-02
# 63                 1.540026  3.408750e-03  4.733308e-02
